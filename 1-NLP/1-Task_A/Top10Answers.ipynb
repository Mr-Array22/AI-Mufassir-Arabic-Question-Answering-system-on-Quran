# %%
import pandas as pd

# %%
column = ["qid", "Q0", "docno", "rank", "score", "tag"]
df1 = pd.read_table('bigIR_run02.tsv', names=column)



df2 = pd.read_table('ArabicBERT_run.tsv', names=column)

# %%
df1
# Out:
#       qid  Q0       docno  rank     score              tag
# 0     500  Q0    29:24-27     1  0.750652  bigIR_run02.tsv
# 1     500  Q0     2:34-39     2  0.740425  bigIR_run02.tsv
# 2     500  Q0    21:51-68     3  0.735212  bigIR_run02.tsv
# 3     500  Q0    10:79-86     4  0.725035  bigIR_run02.tsv
# 4     500  Q0     3:54-58     5  0.724141  bigIR_run02.tsv
# ...   ...  ..         ...   ...       ...              ...
# 1035  613  Q0    22:14-15    16  0.785964  bigIR_run02.tsv
# 1036  613  Q0    29:56-60    17  0.784790  bigIR_run02.tsv
# 1037  613  Q0    36:20-27    18  0.783031  bigIR_run02.tsv
# 1038  613  Q0  11:103-108    19  0.779976  bigIR_run02.tsv
# 1039  613  Q0    16:30-32    20  0.778267  bigIR_run02.tsv
#
# [1040 rows x 6 columns]

# %%
df2
# Out:
#       qid  Q0     docno  rank     score             tag
# 0     500  Q0  21:69-73     1  0.686223  ArabicBERT_run
# 1     500  Q0  37:83-98     2  0.616372  ArabicBERT_run
# 2     500  Q0  19:41-50     3  0.603758  ArabicBERT_run
# 3     500  Q0  21:51-68     4  0.586523  ArabicBERT_run
# 4     500  Q0  14:35-41     5  0.572665  ArabicBERT_run
# ...   ...  ..       ...   ...       ...             ...
# 1035  613  Q0  13:28-29    16  0.465570  ArabicBERT_run
# 1036  613  Q0  13:12-13    17  0.464611  ArabicBERT_run
# 1037  613  Q0  33:36-40    18  0.463951  ArabicBERT_run
# 1038  613  Q0  16:43-50    19  0.454875  ArabicBERT_run
# 1039  613  Q0  48:27-29    20  0.453006  ArabicBERT_run
#
# [1040 rows x 6 columns]

# %% [markdown]
# # Extract the first 10 answers

# %%
qid2=[]
Q02=[]
docno2=[]
score2=[]
tag2=[]
rank2=[]

flage=df1["qid"][0]
num=1
listate=[]
for index, row in df1.iterrows():
  if flage != row["qid"]:
    num=1
    flage = row["qid"]
    qid2.append(row["qid"])
    Q02.append(row["Q0"])
    docno2.append(row["docno"])
    score2.append(row["score"])
    tag2.append(row["tag"])
    rank2.append(num)
  else:
    if num <= 10:
      qid2.append(row["qid"])
      Q02.append(row["Q0"])
      docno2.append(row["docno"])
      score2.append(row["score"])
      tag2.append(row["tag"])
      rank2.append(num)

  num=num+1

dataa2 = {"qid":qid2, "Q0":Q02, "docno":docno2, "rank":rank2, "score":score2, "tag":tag2}


df1_final = pd.DataFrame(dataa2)
df1_final
# Out:
#      qid  Q0     docno  rank     score              tag
# 0    500  Q0  29:24-27     1  0.750652  bigIR_run02.tsv
# 1    500  Q0   2:34-39     2  0.740425  bigIR_run02.tsv
# 2    500  Q0  21:51-68     3  0.735212  bigIR_run02.tsv
# 3    500  Q0  10:79-86     4  0.725035  bigIR_run02.tsv
# 4    500  Q0   3:54-58     5  0.724141  bigIR_run02.tsv
# ..   ...  ..       ...   ...       ...              ...
# 515  613  Q0  13:12-13     6  0.814105  bigIR_run02.tsv
# 516  613  Q0     8:1-4     7  0.813566  bigIR_run02.tsv
# 517  613  Q0  32:28-30     8  0.806933  bigIR_run02.tsv
# 518  613  Q0  35:27-28     9  0.803707  bigIR_run02.tsv
# 519  613  Q0  13:18-24    10  0.800441  bigIR_run02.tsv
#
# [520 rows x 6 columns]

# %%
df1_final['tag'] = 'bigIR_run03'

# %%
df1_final
# Out:
#      qid  Q0     docno  rank     score          tag
# 0    500  Q0  29:24-27     1  0.750652  bigIR_run03
# 1    500  Q0   2:34-39     2  0.740425  bigIR_run03
# 2    500  Q0  21:51-68     3  0.735212  bigIR_run03
# 3    500  Q0  10:79-86     4  0.725035  bigIR_run03
# 4    500  Q0   3:54-58     5  0.724141  bigIR_run03
# ..   ...  ..       ...   ...       ...          ...
# 515  613  Q0  13:12-13     6  0.814105  bigIR_run03
# 516  613  Q0     8:1-4     7  0.813566  bigIR_run03
# 517  613  Q0  32:28-30     8  0.806933  bigIR_run03
# 518  613  Q0  35:27-28     9  0.803707  bigIR_run03
# 519  613  Q0  13:18-24    10  0.800441  bigIR_run03
#
# [520 rows x 6 columns]

# %%
df1_final.to_csv("bigIR_run03.tsv", sep='\t', index=False, header=False)

# %%
! git clone https://gitlab.com/bigirqu/quran-qa-2023.git
# Out:
# Cloning into 'quran-qa-2023'...
# remote: Enumerating objects: 1018, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 1018 (delta 32), reused 0 (delta 0), pack-reused 963
# Receiving objects: 100% (1018/1018), 1.14 MiB | 4.62 MiB/s, done.
# Resolving deltas: 100% (479/479), done.

# %%
! python /content/quran-qa-2023/Task-A/code/QQA23_TaskA_submission_checker.py \
    -m "bigIR_run03.tsv"
# Out:
# Format check: Passed

# %%
qid2=[]
Q02=[]
docno2=[]
score2=[]
tag2=[]
rank2=[]

flage=df2["qid"][0]
num=1
listate=[]
for index, row in df2.iterrows():
  if flage != row["qid"]:
    num=1
    flage = row["qid"]
    qid2.append(row["qid"])
    Q02.append(row["Q0"])
    docno2.append(row["docno"])
    score2.append(row["score"])
    tag2.append(row["tag"])
    rank2.append(num)
  else:
    if num <= 10:
      qid2.append(row["qid"])
      Q02.append(row["Q0"])
      docno2.append(row["docno"])
      score2.append(row["score"])
      tag2.append(row["tag"])
      rank2.append(num)

  num=num+1

dataa2 = {"qid":qid2, "Q0":Q02, "docno":docno2, "rank":rank2, "score":score2, "tag":tag2}


df2_final = pd.DataFrame(dataa2)
df2_final
# Out:
#      qid  Q0     docno  rank     score             tag
# 0    500  Q0  21:69-73     1  0.686223  ArabicBERT_run
# 1    500  Q0  37:83-98     2  0.616372  ArabicBERT_run
# 2    500  Q0  19:41-50     3  0.603758  ArabicBERT_run
# 3    500  Q0  21:51-68     4  0.586523  ArabicBERT_run
# 4    500  Q0  14:35-41     5  0.572665  ArabicBERT_run
# ..   ...  ..       ...   ...       ...             ...
# 515  613  Q0  13:18-24     6  0.538121  ArabicBERT_run
# 516  613  Q0  21:89-90     7  0.528225  ArabicBERT_run
# 517  613  Q0  39:21-26     8  0.520362  ArabicBERT_run
# 518  613  Q0  35:27-28     9  0.518636  ArabicBERT_run
# 519  613  Q0   10:7-10    10  0.508486  ArabicBERT_run
#
# [520 rows x 6 columns]

# %%
df2_final['tag'] = "bigIR_run04"
df2_final
# Out:
#      qid  Q0     docno  rank     score          tag
# 0    500  Q0  21:69-73     1  0.686223  bigIR_run04
# 1    500  Q0  37:83-98     2  0.616372  bigIR_run04
# 2    500  Q0  19:41-50     3  0.603758  bigIR_run04
# 3    500  Q0  21:51-68     4  0.586523  bigIR_run04
# 4    500  Q0  14:35-41     5  0.572665  bigIR_run04
# ..   ...  ..       ...   ...       ...          ...
# 515  613  Q0  13:18-24     6  0.538121  bigIR_run04
# 516  613  Q0  21:89-90     7  0.528225  bigIR_run04
# 517  613  Q0  39:21-26     8  0.520362  bigIR_run04
# 518  613  Q0  35:27-28     9  0.518636  bigIR_run04
# 519  613  Q0   10:7-10    10  0.508486  bigIR_run04
#
# [520 rows x 6 columns]

# %%
df2_final.to_csv("bigIR_run04.tsv", sep='\t', index=False, header=False)

# %%
! python /content/quran-qa-2023/Task-A/code/QQA23_TaskA_submission_checker.py \
    -m "bigIR_run04.tsv"
# Out:
# Format check: Passed
